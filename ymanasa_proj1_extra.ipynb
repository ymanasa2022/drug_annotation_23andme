# %% [markdown]
# # Extra Credit
# ## Project option 1 - Drug annotation of 23andme report
#
#
# Columns in the **23andme_v5_hg19_ref.txt** file are:
# - CHR: the chromosome number
# - POS: the position of the variant - position where the difference in nucleotides is found
# - dbSNP_ID: the variant identifier in the dbSNP database (https://www.ncbi.nlm.nih.gov/snp/) (this field will contain a dot . when the SNP is not available in the dbSNP database)
# - **ALLELE_23andme** : ALLELE: the nucleotides found at that position on the pair of chromosomes
#
#
# Columns in the **var_drug_ann.tsv** file are:
# - Variant Annotation ID: unique ID number for each variant/drug annotation
# - **dbSNP ID** : Variant/Haplotypes: dbSNP ID or haplotype(s)
# - **GENE_SYMBOL** : Gene: HGNC symbol
# - **DRUG_NAME** : Drug(s): Drug name
# - **PMID** : PubMed identifier
# - **PHENOTYPE_CATEGOERY**: Phenotype Category: options [efficacy, toxicity, dosage, metabolism/PK other]
# - **SIGNIFICANCE**: Significance: yes or no – determined by if the author stated the association was significant
# - **NOTES** :Notes: curator notes field
# - **SENTENCE**: Sentence: structured sentence
# - **ALLELE_PharmGKB**: Alleles: variant alleles in annotation
# - Specialty Population: tags for any special populations this annotation is relevant to (e.g. pediatric)
#
# And other columns: Metabolizer types, isPlural, Is/Is Not associated, Direction of effect, PD/PK terms, Multiple drugs And/or, Population types, Population Phenotypes or diseases, Multiple phenotypes or diseases And/or, Comparison Allele(s) or Genotype(s), Comparison Metabolizer types

# %% [markdown]
# ### Q1. Map/merge the 23andme file and the variant-drug annotation file based on dbSNP_ID (also known as rsID).
#
# The merged result should have the following columns:
#
# dbSNP_ID, GENE_SYMBOL, DRUG_NAME, PMID, PHENOTYPE_CATEGORY, SIGNIFICANCE, NOTES, SENTENCE, ALLELE_PharmGKB (variant alleles in annotation), ALLELE_23andme (variant alleles in 23andme file)

# %%
import pandas as pd

# %%
# loading the 23andme data into a dataframe
twentythree_df = pd.read_csv('23andme_v5_hg19_ref.txt', sep='\t', comment='#', header=None, names=['CHR', 'POS', 'dbSNP_ID', 'ALLELE_23andme']).dropna()
twentythree_df.head(2)
# Out:
#     CHR    POS     dbSNP_ID ALLELE_23andme
# 0  chr1  69869  rs548049170              T
# 1  chr1  74792   rs13328684              G

# %%
# loading the var_drug data into a dataframe
# rouge line was taken out in vim manually
drug_df = pd.read_csv('var_drug_ann.tsv', sep='\t', comment='#')
drug_df.head(2)
# Out:
#    Variant Annotation ID   Variant/Haplotypes    Gene     Drug(s)      PMID  \
# 0             1451834452  CYP3A4*1, CYP3A4*17  CYP3A4  nifedipine  15634941
# 1             1451159680            rs5031016  CYP2A6    warfarin  22248286
#
#      Phenotype Category Significance  \
# 0  Other, Metabolism/PK   not stated
# 1                Dosage           no
#
#                                                Notes  \
# 0  in vitro expression of the recombinant CYP3A4*...
# 1  No association was found between this variant ...
#
#                                             Sentence Alleles  ... isPlural  \
# 0  CYP3A4 *17 is associated with decreased metabo...     *17  ...       Is
# 1  Allele G is not associated with increased dose...       G  ...       Is
#
#   Is/Is Not associated Direction of effect    PD/PK terms  \
# 0      Associated with           decreased  metabolism of
# 1  Not associated with           increased        dose of
#
#   Multiple drugs And/or Population types  \
# 0                   NaN              NaN
# 1                   NaN   in people with
#
#                    Population Phenotypes or diseases  \
# 0                                                NaN
# 1  Other:an international normalized ratio (INR) ...
#
#   Multiple phenotypes or diseases And/or Comparison Allele(s) or Genotype(s)  \
# 0                                    NaN                                  *1
# 1                                    NaN                                   A
#
#   Comparison Metabolizer types
# 0                          NaN
# 1                          NaN
#
# [2 rows x 22 columns]

# %%
# renaming relavant column names
col_name_change = {'Variant/Haplotypes': 'dbSNP_ID',
                  'Gene': 'GENE_SYMBOL',
                  'Drug(s)': 'DRUG_NAME',
                  'Phenotype Category': 'PHENOTYPE_CATEGORY',
                  'Significance': 'SIGNIFICANCE',
                  'Notes': 'NOTES',
                  'Sentence': 'SENTENCE',
                  'Alleles': 'ALLELE_PharmGKB'}

drug_df.rename(columns=col_name_change, inplace=True)
drug_df_subset = drug_df[['dbSNP_ID','GENE_SYMBOL', 'DRUG_NAME', 'PMID', 'PHENOTYPE_CATEGORY', 'SIGNIFICANCE', 'NOTES', 'SENTENCE', 'ALLELE_PharmGKB']]
drug_df_subset
# Out:
#                                      dbSNP_ID GENE_SYMBOL   DRUG_NAME  \
# 0                         CYP3A4*1, CYP3A4*17      CYP3A4  nifedipine
# 1                                   rs5031016      CYP2A6    warfarin
# 2      CYP2D6 ultrarapid metabolizer genotype      CYP2D6    tramadol
# 3                                   CYP2C9*11      CYP2C9    warfarin
# 4                         CYP2B6*1, CYP2B6*18      CYP2B6   efavirenz
# ...                                       ...         ...         ...
# 11597                               rs2242480      CYP3A4  tacrolimus
# 11598                               rs7590387       RAMP1    erenumab
# 11599                              rs17844444      PCDHB6   verapamil
# 11600                               rs2230433       ITGAL   verapamil
# 11601                               rs3733694      PCDHB8   verapamil
#
#            PMID    PHENOTYPE_CATEGORY SIGNIFICANCE  \
# 0      15634941  Other, Metabolism/PK   not stated
# 1      22248286                Dosage           no
# 2      18204346         Metabolism/PK          yes
# 3      33350885                Dosage   not stated
# 4      16495778         Metabolism/PK          yes
# ...         ...                   ...          ...
# 11597  38004558         Metabolism/PK          yes
# 11598  34965002              Efficacy           no
# 11599  33829662              Efficacy          yes
# 11600  33829662              Efficacy          yes
# 11601  33829662              Efficacy          yes
#
#                                                    NOTES  \
# 0      in vitro expression of the recombinant CYP3A4*...
# 1      No association was found between this variant ...
# 2      Median (+)R,R-tramadol area under the curve wa...
# 3      "This case suggests that CYP2C9 *11/*11 carrie...
# 4      Please note that in the paper the allele was r...
# ...                                                  ...
# 11597  "CYP3A4*18B genotypes were also significant co...
# 11598  "RAMP1 rs7590387 was found to confer a lower p...
# 11599  "There are 3 highly significant SNPs (p‐value ...
# 11600  "There are 3 highly significant SNPs (p‐value ...
# 11601  "There are 3 highly significant SNPs (p‐value ...
#
#                                                 SENTENCE ALLELE_PharmGKB
# 0      CYP3A4 *17 is associated with decreased metabo...             *17
# 1      Allele G is not associated with increased dose...               G
# 2      CYP2D6 ultra-metabolizer genotype is associate...             NaN
# 3      CYP2C9 *11/*11 is associated with decreased do...         *11/*11
# 4      CYP2B6 *1/*18 is associated with increased con...          *1/*18
# ...                                                  ...             ...
# 11597  Genotypes CT + TT is associated with increased...         CT + TT
# 11598  Allele G is associated with decreased clinical...               G
# 11599  Allele A is associated with decreased clinical...               A
# 11600  Allele C is associated with increased clinical...               C
# 11601  Allele G is associated with decreased clinical...               G
#
# [11602 rows x 9 columns]

# %%
# merging and only taking necessary columns 
merged_df = pd.merge(twentythree_df, drug_df_subset, on='dbSNP_ID')
result_df = merged_df[['dbSNP_ID', 'GENE_SYMBOL', 'DRUG_NAME', 'PMID', 'PHENOTYPE_CATEGORY', 'SIGNIFICANCE', 'NOTES', 'SENTENCE', 'ALLELE_PharmGKB', 'ALLELE_23andme']]

result_df
# Out:
#         dbSNP_ID GENE_SYMBOL  \
# 0     rs11807862      PRDM16
# 1       rs228729        PER3
# 2       rs228642        PER3
# 3       rs228666        PER3
# 4       rs228697        PER3
# ...          ...         ...
# 5664   rs3810651       GABRQ
# 5665     rs17435       MECP2
# 5666   rs1734787       MECP2
# 5667   rs1734791       MECP2
# 5668   rs1050828        G6PD
#
#                                               DRUG_NAME      PMID  \
# 0     atorvastatin, hmg coa reductase inhibitors, si...  24096969
# 1                                               lithium  21781277
# 2                                               lithium  21781277
# 3                                               lithium  21781277
# 4                                               lithium  21781277
# ...                                                 ...       ...
# 5664                             botulinum toxin type a  31014225
# 5665              cisplatin, fluorouracil, mitoxantrone  21635146
# 5666              cisplatin, fluorouracil, mitoxantrone  21635146
# 5667              cisplatin, fluorouracil, mitoxantrone  21635146
# 5668                        artemisinin and derivatives  22940027
#
#      PHENOTYPE_CATEGORY SIGNIFICANCE  \
# 0              Efficacy           no
# 1              Efficacy           no
# 2              Efficacy           no
# 3              Efficacy           no
# 4              Efficacy           no
# ...                 ...          ...
# 5664           Efficacy           no
# 5665           Efficacy          yes
# 5666           Efficacy          yes
# 5667           Efficacy          yes
# 5668           Efficacy           no
#
#                                                   NOTES  \
# 0     There could be strand confusion with this A/T ...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5664  No significant difference in allele frequency ...
# 5665  The study described this variant within the ME...
# 5666  The study described this variant within the ME...
# 5667  The study described this variant within the ME...
# 5668  G6PD deficient (those with genotype TT, TC, or...
#
#                                                SENTENCE ALLELE_PharmGKB  \
# 0     Genotype AA is associated with decreased respo...              AA
# 1     Allele T is not associated with increased resp...               T
# 2     Allele C is not associated with increased resp...               C
# 3     Allele C is not associated with increased resp...               C
# 4     Allele G is not associated with increased resp...               G
# ...                                                 ...             ...
# 5664  Allele T is not associated with response to bo...               T
# 5665  Allele A is associated with response to cispla...               A
# 5666  Allele A is associated with response to cispla...               A
# 5667  Allele A is associated with response to cispla...               A
# 5668  Allele T is not associated with response to ar...               T
#
#      ALLELE_23andme
# 0                 T
# 1                 T
# 2                 C
# 3                 T
# 4                 C
# ...             ...
# 5664              T
# 5665              T
# 5666              A
# 5667              A
# 5668              C
#
# [5669 rows x 10 columns]

# %% [markdown]
# ### Q2. Filter the output so that it only contains significant associations (SIGNIFICANCE is yes) for variants that affect the drug efficacy (`PHENOTYPE_CATEGORY` is `efficacy`).

# %%
filtered_df = result_df[(result_df['SIGNIFICANCE'] == 'yes') & (result_df['PHENOTYPE_CATEGORY'] == 'Efficacy')]
filtered_df
# Out:
#        dbSNP_ID GENE_SYMBOL  \
# 8     rs1801131       MTHFR
# 9     rs1801131       MTHFR
# 11    rs1801131       MTHFR
# 14    rs1801131       MTHFR
# 15    rs1801131       MTHFR
# ...         ...         ...
# 5660   rs502434       GRIA3
# 5663  rs3810651       GABRQ
# 5665    rs17435       MECP2
# 5666  rs1734787       MECP2
# 5667  rs1734791       MECP2
#
#                                               DRUG_NAME      PMID  \
# 8                                           oxaliplatin  20385995
# 9                 Vitamin B-complex, Incl. Combinations  27035272
# 11                                         methotrexate  25618758
# 14                                         methotrexate  23198157
# 15                                         methotrexate  24386571
# ...                                                 ...       ...
# 5660  Selective serotonin reuptake inhibitors, venla...  23394390
# 5663                                        venlafaxine  23394390
# 5665              cisplatin, fluorouracil, mitoxantrone  21635146
# 5666              cisplatin, fluorouracil, mitoxantrone  21635146
# 5667              cisplatin, fluorouracil, mitoxantrone  21635146
#
#      PHENOTYPE_CATEGORY SIGNIFICANCE  \
# 8              Efficacy          yes
# 9              Efficacy          yes
# 11             Efficacy          yes
# 14             Efficacy          yes
# 15             Efficacy          yes
# ...                 ...          ...
# 5660           Efficacy          yes
# 5663           Efficacy          yes
# 5665           Efficacy          yes
# 5666           Efficacy          yes
# 5667           Efficacy          yes
#
#                                                   NOTES  \
# 8     Statistics given as trend for increased overal...
# 9     Please note that allele has been complemented ...
# 11    Alleles given as C and A. Efficacy of treatmen...
# 14    Patients with the GG genotype had better overa...
# 15    Patients with the TT genotype had significantl...
# ...                                                 ...
# 5660  Regression model looking at interaction betwee...
# 5663  Those with the AA/AT genotype are more likely ...
# 5665  The study described this variant within the ME...
# 5666  The study described this variant within the ME...
# 5667  The study described this variant within the ME...
#
#                                                SENTENCE ALLELE_PharmGKB  \
# 8     Genotypes GG + GT are associated with increase...         GG + GT
# 9     Allele G is associated with increased response...               G
# 11    Genotype GT is associated with decreased respo...              GT
# 14    Genotype GG is associated with increased respo...              GG
# 15    Genotype TT is associated with decreased respo...              TT
# ...                                                 ...             ...
# 5660  Genotype CC is associated with decreased respo...              CC
# 5663  Genotypes AA + AT are associated with increase...         AA + AT
# 5665  Allele A is associated with response to cispla...               A
# 5666  Allele A is associated with response to cispla...               A
# 5667  Allele A is associated with response to cispla...               A
#
#      ALLELE_23andme
# 8                 T
# 9                 T
# 11                T
# 14                T
# 15                T
# ...             ...
# 5660              T
# 5663              T
# 5665              T
# 5666              A
# 5667              A
#
# [1311 rows x 10 columns]

# %% [markdown]
# ### Q3. Save the output of the filtering step in a tab-separated file (23andme_PharmGKB_map.tsv) with the following columns:
# dbSNP_ID, GENE_SYMBOL, DRUG_NAME, NOTES, SENTENCE, ALLELE_PharmGKB, ALLELE_23andme

# %%
filtered_subset = filtered_df[['dbSNP_ID', 'GENE_SYMBOL', 'DRUG_NAME', 'NOTES', 'SENTENCE', 'ALLELE_PharmGKB', 'ALLELE_23andme']]
filtered_subset.to_csv('23andme_PharmGKB_map.tsv', sep='\t', index=False)

# %% [markdown]
# ### Q4. Create a tab separated file (23andme_PharmGKB_summary.tsv) with summarized data with the following columns:
# GENE_SYMBOL, DRUG_NAME, dbSNP_IDs (list of IDs separated by ";")

# %%
summary_tsv = filtered_df[['GENE_SYMBOL', 'DRUG_NAME', 'dbSNP_ID']]
summary_tsv.to_csv('23andme_PharmGKB_summary.tsv', sep='\t', index=False)

# %% [markdown]
# ### Q5. Plot the distribution (histogram) of the number of drugs associated with a gene, and the number of SNPs for a gene.

# %%
# number of snps associated with each gene
gene_snp_counts = filtered_subset.groupby('GENE_SYMBOL')['dbSNP_ID'].nunique().reset_index()
gene_snp_counts
# Out:
#     GENE_SYMBOL  dbSNP_ID
# 0         ABCA1         2
# 1         ABCB1         4
# 2         ABCC1         6
# 3         ABCC2         2
# 4         ABCC4         2
# ..          ...       ...
# 410       XRCC3         1
# 411       XRCC4         1
# 412      ZNF432         1
# 413      ZNF697         1
# 414     ZNF804A         1
#
# [415 rows x 2 columns]

# %%
# number of drugs associated with each gene
gene_drug_counts = filtered_subset.groupby('GENE_SYMBOL')['DRUG_NAME'].nunique().reset_index()
gene_drug_counts
# Out:
#     GENE_SYMBOL  DRUG_NAME
# 0         ABCA1          2
# 1         ABCB1         16
# 2         ABCC1          2
# 3         ABCC2          8
# 4         ABCC4          2
# ..          ...        ...
# 410       XRCC3          2
# 411       XRCC4          1
# 412      ZNF432          1
# 413      ZNF697          1
# 414     ZNF804A          1
#
# [415 rows x 2 columns]
